# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
# some useful scripts 
from libs import utils

# %%
files = [os.path.join('celeba', file_i)
             for file_i in os.listdir('celeba')
             if '.jpg' in file_i]

# %%
img = plt.imread(files[23])

# %%
plt.imshow(img)

# %%
plt.imshow(img[:, :, 0])
#plt.imshow(img[:, :, 1], cmap='gray')
#plt.imshow(img[:, :, 2], cmap='gray')

# %%
plt.imshow(img[:, :, 1], cmap='gray')

# %%
data = np.array(files)
data.shape
# Out:
# (13696,)

# %%
images = [plt.imread(f_i) for f_i in files]

# %%
len(images)
# Out:
# 13696

# %%
plt.imshow(images[12345])

# %%
data = np.array(images)
data.shape
# Out:
# (13696, 218, 178, 3)

# %%
mean_img = np.mean(data, axis=0)
plt.imshow(mean_img.astype(np.uint8))
